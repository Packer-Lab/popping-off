# %%
import os, sys
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
import pickle
import sklearn.linear_model
import sklearn.model_selection
import sklearn.metrics
import sklearn.decomposition
import sklearn.cluster
import h5py
import seaborn as sns
import pandas as pd
import scipy.sparse
import scipy.stats
from cycler import cycler
import itertools

plt.rcParams['axes.prop_cycle'] = cycler(color=sns.color_palette('colorblind'))

# %%
zm_data = dict()

## Load zero-meaned data from sarah (from subspace_preprocess_thijs nb)
zm_data['sarah'] = dict()

cwd = os.getcwd()
os.chdir('/home/thijs/Google Drive/oxford/packerlab/data_sarah')
hfile = h5py.File('data_sarah_s1s2_zero_mean_2019-07-24_RL042_B2_2P_t003.h5', 'r')  # open with read access
for key in hfile.keys():
    try:
        zm_data['sarah'][key] = np.array(hfile[key][()], dtype=np.float32)
    except ValueError: # cannot be converted to float, because it is e.g. the name str
        pass
os.chdir(cwd)
print(f'Keys of zero-mean sarah data: {zm_data["sarah"].keys()}')
hfile.close()
# Out:
# Keys of zero-mean sarah data: dict_keys(['dff_s1', 'dff_s1_mean', 'dff_s2', 'dff_s2_mean', 'spikes_s1', 'spikes_s1_mean', 'spikes_s2', 'spikes_s2_mean'])

# %%
## Load zero-meaned data from semedo ea (from matlab preprocessing file)
cwd = os.getcwd()
os.chdir('/home/thijs/Google Drive/oxford/packerlab/data_semedo/v1-v2_gratings/h5_data')
hfile = h5py.File('data_semedo_v1v2_zero_mean_stimindep.h5', 'r')  # open with read access

dict_names_samples = {'107l002p67': 'm1',
                      '107l003p143': 'm2',
                      '106r001p26': 'm3',
                      '105l001p16': 'm4',
                      '106r002p70': 'm5'}

def load_semedo_data(data_path, obj):
    if isinstance(obj, h5py.Dataset):  # if object is a dataset
        ## Currenty hard-coded identities, identify from data path:
        sample = data_path.split('/')[0]
        stimulus = data_path.split('/')[1]
        type_region = data_path.split('/')[2]
        
        name_dataset = 'semedo_' + dict_names_samples[sample] + '_st' + stimulus[-1]  # name for this data set (per sample and stimulus)
        if name_dataset not in zm_data.keys():  # create entry if necessary
            zm_data[name_dataset] = dict()
        
        zm_data[name_dataset][type_region] = np.array(obj[()], dtype=np.float32)  # load data
        
        # Note that if you load indices, they are 1-indexed!!! (matlab-style) so they should be corrected:
        if type_region[-7:] == 'indices':
            zm_data[name_dataset][type_region] -= 1
        
hfile.visititems(load_semedo_data)  # visit all items in h5 file recursively and call function
semedo_name_list = [x for x in zm_data.keys() if x[:4] == 'seme']
n_semedo_ds = len(semedo_name_list)
os.chdir(cwd)
print(f'Keys of zero-mean semedo data: {zm_data["semedo_m2_st5"].keys()}')
hfile.close()
# Out:
# Keys of zero-mean semedo data: dict_keys(['spikes_v1', 'spikes_v1_indices', 'spikes_v1_mean', 'spikes_v2', 'spikes_v2_indices', 'spikes_v2_mean'])

# %% [markdown]
# ## Inspect data

# %%
plt.rcParams['figure.figsize'] = (5, 3)

for data_name in ['spikes_v1', 'spikes_v2']:
    tmp_semedo_hist_data = np.array([])
    for x in zm_data.keys():
        if 'semedo_' in x:
            tmp_semedo_hist_data = np.concatenate((tmp_semedo_hist_data, 
                                                   zm_data[x][data_name].reshape(-1)))
    plt.hist(tmp_semedo_hist_data / 1, histtype='step', linewidth=2,
             bins=np.linspace(-4, 6, 60), density=True, label='semedo_' + data_name);
for data_name in ['dff_s1', 'dff_s2']:
    plt.hist(zm_data['sarah'][data_name].reshape(-1), histtype='step', linewidth=2,
             bins=np.linspace(-4, 6, 60), density=True, label='sarah_' + data_name);
    
plt.legend()
plt.title('Distribution of all data'); plt.xlabel('data'); plt.ylabel('Probability');

# %%
plt.rcParams['figure.figsize'] = (5, 3)

metric_plot = 'mean'

if metric_plot == 'std':
    for data_name in ['spikes_v1', 'spikes_v2']:
        plt.hist(zm_data['semedo'][data_name].std(1) / 1, histtype='step', linewidth=2,
                 bins=np.linspace(0, 4, 20), density=True, label='semedo_' + data_name);
    for data_name in ['dff_s1', 'dff_s2']:
        plt.hist(zm_data['sarah'][data_name].std(1), histtype='step', linewidth=2,
                 bins=np.linspace(0, 4, 20), density=True, label='sarah_' + data_name);

elif metric_plot == 'mean':
    plot_bins = np.linspace(-3, 3, 40)
#     for data_name in ['spikes_v1', 'spikes_v2']:
#         plt.hist(zm_data['semedo'][data_name + '_mean'].sum(1) / 1, histtype='step', linewidth=2,
#                  bins=plot_bins, density=False, label='semedo_' + data_name);
    for data_name in ['dff_s1', 'dff_s2']:
        plt.hist((zm_data['sarah'][data_name + '_mean']).sum(1), histtype='step', linewidth=2,
                 bins=plot_bins, density=False, label='sarah_' + data_name);

plt.legend()
plt.title(f'Distribution of {metric_plot} data'); plt.xlabel('data'); plt.ylabel('Probability');

# %% [markdown]
# # Define source and target populations

# %%
## TODO: do fancy FR-corrected random sampling

source = {}
target = {}
n_source = {}
n_target = {}

def add_to_source_target(data_or, name_1, name_2, bin_size=None,
                         select_method='fr-corr', min_st1_ratio=0.7):
    """
    
    Arguments:
        data_or: str
            data origin name 
        name_1: str 
            name of first data set (eg spikes_s1)
        name_2: str
            name of second data set
        bin_size: float = None (-> will be defined in code)
            size of bin for FR correcti
        min_st1_ratio:float = 0.7
            minimum factor of source neurons
        select_method: str
            'random' for unbiased random selection of 1 target, 'fr-corr' for firing rate corrected.
    """
    
    n_v1 = zm_data[data_or][name_1].shape[0]
    n_v2 = zm_data[data_or][name_2].shape[0]
    if select_method == 'random':
        n_v1_s = np.maximum(n_v1 - n_v2, int(np.round(min_st1_ratio * n_v1)))
        n_v1_t = n_v1 - n_v1_s
        inds_v1_s = np.random.choice(a=n_v1, size=n_v1_s, replace=False)
        inds_v1_t = np.array(list(set(np.arange(n_v1)).difference(set(inds_v1_s))))
        inds_v2_t = np.arange(n_v2)
        
    elif select_method == 'fr-corr':
        inds_v1_s, inds_v1_t, inds_v2_t = np.array([]), np.array([]), np.array([])  # initiate empty indices
        
        if data_or[:6] == 'semedo':
            if bin_size is None:
                bin_size = 5  # FR bins
            freq = 10  # hard coded from matlab export code
        elif data_or[:5] == 'sarah':
            if name_1[:3] == 'dff' and name_2[:3] == 'dff':
                if bin_size is None:
                    bin_size = 1
                freq = 11.5  # hard-coded, from preprocessing nb
        
        if zm_data[data_or][name_1 + '_mean'].ndim == 2:
            means_1 = zm_data[data_or][name_1 + '_mean'].mean(1) * freq  # go to Hz
            means_2 = zm_data[data_or][name_2 + '_mean'].mean(1) * freq
        elif zm_data[data_or][name_1 + '_mean'].ndim == 1:
            print('only 1 dimension; abort')
            return None
#             means_1 = zm_data[data_or][name_1].mean(1) * freq  # go to Hz
#             means_2 = zm_data[data_or][name_2].mean(1) * freq
            
        if data_or[:6] == 'semedo':
            bin_max = np.ceil(np.maximum(np.max(means_1), np.max(means_2)) 
                              / bin_size) * bin_size  # get max bin with interval bin_size
            bin_min = 0
        elif data_or[:5] == 'sarah':
            bin_max = 5    
            bin_min = np.floor(np.minimum(np.min(means_1), np.min(means_2)) 
                              / bin_size) * bin_size  # get max bin with interval bin_size
            
        hist_bins = np.linspace(bin_min, bin_max, int((bin_max - bin_min) / bin_size + 1))  # make bin edges
        
        count_1, bin_edges = np.histogram(means_1, bins=hist_bins)  # compute histogram for both
        count_2, bin_edges = np.histogram(means_2, bins=hist_bins)
        
        def add_indices(bin_low, bin_high, sample_size):
            all_inds_1 = np.where(np.logical_and(means_1 < bin_high, means_1 >= bin_low))[0]  # find indices in this bin
            sampled_inds_1 = np.random.choice(a=all_inds_1, size=sample_size, replace=False)  # sample target pop from these
            
            all_inds_2 = np.where(np.logical_and(means_2 < bin_high, means_2 >= bin_low))[0]
            sampled_inds_2 = np.random.choice(a=all_inds_2, size=sample_size, replace=False)
            
            sampled_inds_s = np.array(list(set(all_inds_1).difference(set(sampled_inds_1))))
            
            return sampled_inds_1, sampled_inds_2, sampled_inds_s
        
        for i_bin, low_bin in enumerate(bin_edges[:-1]):  # loop through bins
            t_size = np.minimum(count_1[i_bin], count_2[i_bin])  # minimum determines target size (semedo ea)
            if data_or[:5] == 'sarah':
                t_size = int(t_size * 0.4) ## NB: hard-coded change to decrease target size of sarah's data set ( to align with semedo's)
            tmp_1t, tmp_2t, tmp_s = add_indices(bin_low=low_bin, bin_high=bin_edges[i_bin + 1], sample_size=t_size)
            assert len(tmp_1t) == len(tmp_2t)
            inds_v1_t = np.concatenate((inds_v1_t, tmp_1t))  # add to current indices
            inds_v2_t = np.concatenate((inds_v2_t, tmp_2t))
            inds_v1_s = np.concatenate((inds_v1_s, tmp_s))
        
        ## Now we'll pool all data > bin_max
        all_inds_1 = np.where(means_1 >= bin_edges[-1])[0]
        all_inds_2 = np.where(means_2 >= bin_edges[-1])[0]
        t_size = np.minimum(len(all_inds_1), len(all_inds_2))
        
        tmp_1t, tmp_2t, tmp_s = add_indices(bin_low=bin_edges[-1], bin_high=1e6, sample_size=t_size)
        inds_v1_t = np.concatenate((inds_v1_t, tmp_1t))
        inds_v2_t = np.concatenate((inds_v2_t, tmp_2t))
        inds_v1_s = np.concatenate((inds_v1_s, tmp_s))
        
        assert len(inds_v1_t) == len(inds_v2_t)
        n_v1_s = len(inds_v1_s)
        n_v1_t = len(inds_v1_t)
    
    inds_v1_s = inds_v1_s.astype(int)
    inds_v1_t, inds_v2_t = inds_v1_t.astype(int), inds_v2_t.astype(int)
    source[data_or] = zm_data[data_or][name_1][inds_v1_s, :].copy()
    target[data_or] = {}
    target[data_or]['1'] = zm_data[data_or][name_1][inds_v1_t, :].copy()
    target[data_or]['2'] = zm_data[data_or][name_2][inds_v2_t, :].copy()
    n_source[data_or] = n_v1_s
    n_target[data_or] = n_v1_t
    return inds_v1_s, inds_v1_t, inds_v2_t
    
zm_data['semedo'] = zm_data['semedo_m1_st4']
tmp_s, tmp_t1, tmp_t2 = add_to_source_target(data_or='semedo', name_1='spikes_v1', 
                                             name_2='spikes_v2', select_method='fr-corr')

tmp_s, tmp_t1, tmp_t2 = add_to_source_target(data_or='sarah', name_1='dff_s1', 
                                             name_2='dff_s2', select_method='fr-corr')

print(target['sarah']['2'].shape)
# Out:
# (141, 2300)

# %% [markdown]
# ## Correlations
# Recreate fig 2A from Semedo ea (merge the top and bottom panel), per data set
#
# Note: Inferring from the number of pairs in fig 2A, it seems that they pooled all stimuli (as opposed to the rest of the paper). So these are all pairs from 5 data sets (instead of 40). It will take quite some adjustment to make my code compatible with this (incl FR-corrected splitting). But as results seem ok per stimulus (instead of across stimuli), I'll leave it be.

# %%
def correlation_matrix(sdata, tdata):
    assert sdata.shape[1] == tdata.shape[1]
    corr_mat = np.corrcoef(sdata, tdata)  # use np to compute full correlation matrix
    return corr_mat

plt.rcParams['figure.figsize'] = (10, 5)
for i_data, data_or in enumerate(['sarah', 'semedo']):
    for tname in ['1', '2']:
        cmat = correlation_matrix(sdata= source[data_or], 
                                         tdata=target[data_or][tname])
        cmat = cmat[:n_source[data_or], n_target[data_or]:]  # only select interactions between s and t
        plt.subplot(1, 2, i_data + 1)
        plt.hist(cmat.reshape(-1), histtype='step', linewidth=2, 
                 bins=np.linspace(-0.1, 0.5, 13), label=data_or + '_' + tname)
    plt.legend(); plt.title(data_or); plt.xlabel('pw corr'); plt.ylabel('freq');
# Out:
# /home/thijs/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:12: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   if sys.path[0] == '':

# %% [markdown]
# ## Regress target versus source
# Recreate fig 2B (merged). Only look at multivar regression (and not the single neuron case).

# %%
def multivar_regression(sdata, tdata, n_cv=5, delta_t=0):
    """Perform multivar regression and assess R2 of test data
    
    Arguments:
    ----------------
        sdata: np.array
            source data (n_cells_s x n_times)
        tdata: np.array
            target dtaa (n_cells_t x n_times)
        n_cv: int = 5
            number of cv folds
        delta_t: int = 1
            how many time steps to predict into the future 
    
    Returns:
    -------------------
        model: sklearn.linear_model.LinearRegression
            full regression model 
        r2_test: np.array
            1D array of r2 per target neuron
    """
    
    assert sdata.shape[1] == tdata.shape[1]
    n_total = tdata.shape[1]  # number of time points
    
    if delta_t == 0:
        kf = sklearn.model_selection.KFold(n_splits=n_cv)
        alpha_array = np.logspace(-2, 7, 10)
        r2_test_kf = np.zeros((len(alpha_array), n_cv))
        
        for i_alpha, alpha_param in enumerate(alpha_array):
            i_kf = 0
            for train_inds, test_inds in kf.split(np.arange(n_total)):
    #             model = sklearn.linear_model.LinearRegression()
                model = sklearn.linear_model.Ridge(alpha=alpha_param)
    #             model = sklearn.linear_model.Lasso(alpha=0.1)
                model.fit(X=sdata[:, train_inds].T, y=tdata[:, train_inds].T)  # fit to train data
                pred_tdata = model.predict(X=sdata[:, test_inds].T)  # predict traces for test data set
                r2_test_kf[i_alpha, i_kf] = sklearn.metrics.r2_score(y_true=tdata[:, test_inds].T, y_pred=pred_tdata,
                                              multioutput='variance_weighted')
                i_kf += 1
        r2_alpha = np.mean(r2_test_kf, 1)
#         print(alpha_array[np.argmax(r2_alpha)], np.max(r2_alpha))
#         print(r2_alpha)
        r2_test = np.max(r2_alpha)
    else:    
        n_train = int(np.round((n_cv - 1) / n_cv * tdata.shape[1]))  # use first section for training -> bias?
        model = sklearn.linear_model.LinearRegression()
        model.fit(X=sdata[:, :int(n_train - delta_t)].T, y=tdata[:, delta_t:n_train].T)  # fit to train data
        pred_tdata = model.predict(X=sdata[:, n_train:(n_total - delta_t)].T)  # predict traces for test data set
        sst = np.power((pred_tdata.T - tdata[:, (n_train + delta_t):]), 2).sum(1)  # total error squared
        mse = np.power((tdata[:, (n_train + delta_t):] -
                        tdata[:, (n_train + delta_t):].mean(1)[:, np.newaxis]), 2).sum(1)  # mean squared error
        r2_test = 1 - sst/mse
    return model, r2_test

class ReducedRankRegressor(object):
    """
    
    https://github.com/riscy/machine_learning_linear_models/blob/master/reduced_rank_regressor.py
    
    Reduced Rank Regressor (linear 'bottlenecking' or 'multitask learning')
    - X is an n-by-d matrix of features.
    - Y is an n-by-D matrix of targets.
    - rrank is a rank constraint.
    - reg is a regularization parameter (optional).
    """
    def __init__(self, X, Y, rank, reg=None):
        if np.size(np.shape(X)) == 1:
            X = np.reshape(X, (-1, 1))
        if np.size(np.shape(Y)) == 1:
            Y = np.reshape(Y, (-1, 1))
        if reg is None:
            reg = 0
        self.rank = rank

        CXX = np.dot(X.T, X) + reg * scipy.sparse.eye(np.size(X, 1))
        CXY = np.dot(X.T, Y)
        _U, _S, V = np.linalg.svd(np.dot(CXY.T, np.dot(np.linalg.pinv(CXX), CXY)))
        self.W = V[0:rank, :].T
        self.A = np.dot(np.linalg.pinv(CXX), np.dot(CXY, self.W)).T

    def __str__(self):
        return 'Reduced Rank Regressor (rank = {})'.format(self.rank)

    def predict(self, X):
        """Predict Y from X."""
        if np.size(np.shape(X)) == 1:
            X = np.reshape(X, (-1, 1))
        return np.dot(X, np.dot(self.A.T, self.W.T))

def red_rank_regression(sdata, tdata, rank=5, n_cv=5):
    assert sdata.shape[1] == tdata.shape[1]
    n_total = tdata.shape[1]  # number of time points
    kf = sklearn.model_selection.KFold(n_splits=n_cv)
    r2_test_kf = np.zeros((n_cv))
    i_kf = 0
    for train_inds, test_inds in kf.split(np.arange(n_total)):
        n_train = len(train_inds)
        model = ReducedRankRegressor(X=sdata[:, train_inds].T, Y=tdata[:, train_inds].T,
                                    rank=rank, reg=None)
        pred_tdata = model.predict(X=sdata[:, test_inds].T)  # predict traces for test data set
        r2_test_kf[i_kf] = sklearn.metrics.r2_score(y_true=tdata[:, test_inds].T, y_pred=pred_tdata,
                                          multioutput='variance_weighted')
        i_kf += 1
    r2_test = np.mean(r2_test_kf, 0)
    
    return model, r2_test

# %%
source, target = {}, {}
    
tmp_s, tmp_t1, tmp_t2 = add_to_source_target(data_or='semedo', name_1='spikes_v1', 
                                             name_2='spikes_v2', select_method='fr-corr')

tmp_s, tmp_t1, tmp_t2 = add_to_source_target(data_or='sarah', name_1='dff_s1', 
                                             name_2='dff_s2', select_method='fr-corr')
color_plot = {'1': 'b', '2': 'r'}
t_list = ['1', '2']
av_r2_sarah = {}
plt.rcParams['figure.figsize'] = (6, 6)
for i_data, data_or in enumerate(['sarah']):
    for tname in t_list:
        
        
        _, r2 = multivar_regression(sdata= source[data_or],# rank=3,
                                   tdata=target[data_or][tname])
        print(f'Data {data_or} {tname}, mean r2 {np.mean(r2)}')
        if data_or == 'sarah':
            av_r2_sarah[tname] = np.mean(r2)
#         plt.subplot(2, 2, i_data + 1)
#         plt.hist(r2.reshape(-1), histtype='step', linewidth=2, 
#                  label=data_or + '_' + tname)
#     plt.legend(); plt.title(data_or); plt.xlabel('R2'); plt.ylabel('freq');
    
    
av_r2_semedo = {x: np.zeros(40) for x in t_list} # 40 = 5 samples x 8 stimuli (semedo ea)
n_runs = 25
i_ds = 0
for m_index in tqdm(range(1, 6)):
    for st_index in range(1, 9):
        r2_runs = {x: np.zeros(n_runs) for x in t_list}
        for i_run in range(n_runs):
            source, target = {}, {}
            zm_name = f'semedo_m{m_index}_st{st_index}'
            tmp_s, tmp_t1, tmp_t2 = add_to_source_target(data_or=zm_name, name_1='spikes_v1', 
                                                         bin_size=None,
                                                 name_2='spikes_v2', select_method='fr-corr')
            for tname in t_list:
                r2_runs[tname][i_run] = np.mean(
                    multivar_regression(sdata= source[zm_name], n_cv=5,
                                            tdata=target[zm_name][tname])[1])
            
        for tname in t_list:
            av_r2_semedo[tname][i_ds] = np.mean(r2_runs[tname])
        i_ds += 1
# Out:
# Data sarah 1, mean r2 0.009374126195779533
#   0%|          | 0/5 [00:00<?, ?it/s]
# Data sarah 2, mean r2 -0.002281337530538351
# 100%|██████████| 5/5 [07:43<00:00, 92.66s/it]

# %%
color_plot = {'1': 'b', '2': 'r'}
for i_plot, tname in enumerate(t_list):
    plt.subplot(2, 1, i_plot + 1)
    plt.hist(av_r2_semedo[tname], histtype='stepfilled', label=tname, 
             alpha=0.5, linewidth=3, color=color_plot[str(int(i_plot + 1))],
             bins=np.arange(np.minimum(np.nanmin(av_r2_semedo[tname]), 0), 
                            np.maximum(np.nanmax(av_r2_semedo[tname]), 0.3), 0.025)) 
            
    plt.ylim([0, 15])
    if i_plot == 0:
        plt.title('Average R2 per data set (multivar regression), fig 2B')
    else:
        plt.xlabel('average r2'); 
    plt.ylabel('data sets'); plt.legend();

# %%
tmp = red_rank_regression(sdata=source[data_orig], rank=rrank, tdata=target[data_orig][ttarget])

print(source[data_orig].shape, target[data_orig][ttarget].shape, rrank)
print(tmp[0].A.shape, tmp[0].W.shape)
# Out:
# (79, 4000) (29, 4000) 7
# (7, 79) (29, 7)

# %%
plt.bar(np.arange(29), np.squeeze(np.array(np.sum(np.abs(tmp[0].W), 1))))
# Out:
# <BarContainer object of 29 artists>

# %%
plt.rcParams['figure.figsize'] = (10, 10)
plt.subplot(221)
plt.imshow(tmp[0].A,  cmap='PiYG', vmin=-.2, vmax=.2)

plt.subplot(224)
plt.imshow(tmp[0].W, cmap='PiYG', vmin=-.2, vmax=.2)

plt.subplot(223)
plt.imshow(np.dot(tmp[0].W, tmp[0].A),  cmap='PiYG', vmin=-.2, vmax=.2)

# %%
try:
    del zm_data['semedo']
except KeyError:
    pass

semedo_name_list = [x for x in zm_data.keys() if x[:4] == 'seme']
n_semedo_ds = len(semedo_name_list)
n_runs = 25
n_ranks = 8
r2_semedo_ds = {'1': np.zeros((n_ranks, n_runs, n_semedo_ds)),
                '2': np.zeros((n_ranks, n_runs, n_semedo_ds))}

for run in tqdm(range(n_runs)):   
    for i_data, data_orig in enumerate(semedo_name_list): 
   
        source,target = {}, {}
        tmp_s, tmp_t1, tmp_t2 = add_to_source_target(data_or=data_orig, name_1='spikes_v1', 
                                             name_2='spikes_v2', select_method='fr-corr')
        for rrank in range(n_ranks):
            for ttarget in ['1', '2']:
                 r2_semedo_ds[ttarget][rrank, run, i_data] = np.mean(red_rank_regression(sdata=source[data_orig], 
                                                                    rank=rrank,
                                                                    tdata=target[data_orig][ttarget])[1])
data_orig = 'sarah'
r2_sarah = {'1': np.zeros((n_ranks, n_runs)), 
            '2': np.zeros((n_ranks, n_runs))}
for run in range(n_runs):
    source,target = {}, {}
    tmp_s, tmp_t1, tmp_t2 = add_to_source_target(data_or=data_orig, name_1='dff_s1', 
                                         name_2='dff_s2', select_method='fr-corr')
    for rrank in range(n_ranks):
        for ttarget in ['1', '2']:
             r2_sarah[ttarget][rrank, run] = np.mean(red_rank_regression(sdata=source[data_orig], 
                                                                rank=rrank,
                                                                tdata=target[data_orig][ttarget])[1])
# Out:
#   0%|          | 0/25 [00:00<?, ?it/s]
#
#
#   4%|▍         | 1/25 [00:18<07:31, 18.80s/it]
#
#
#   8%|▊         | 2/25 [00:38<07:16, 18.98s/it]
#
#
#  12%|█▏        | 3/25 [00:59<07:14, 19.77s/it]
#
#
#  16%|█▌        | 4/25 [01:22<07:12, 20.59s/it]
#
#
#  20%|██        | 5/25 [01:41<06:43, 20.20s/it]
#
#
#  24%|██▍       | 6/25 [02:02<06:25, 20.30s/it]
#
#
#  28%|██▊       | 7/25 [02:25<06:19, 21.10s/it]
#
#
#  32%|███▏      | 8/25 [02:46<05:58, 21.09s/it]
#
#
#  36%|███▌      | 9/25 [03:07<05:38, 21.18s/it]
#
#
#  40%|████      | 10/25 [03:29<05:20, 21.36s/it]
#
#
#  44%|████▍     | 11/25 [03:50<04:57, 21.24s/it]
#
#
#  48%|████▊     | 12/25 [04:10<04:32, 20.98s/it]
#
#
#  52%|█████▏    | 13/25 [04:30<04:09, 20.76s/it]
#
#
#  56%|█████▌    | 14/25 [04:52<03:50, 21.00s/it]
#
#
#  60%|██████    | 15/25 [05:13<03:29, 20.99s/it]
#
#
#  64%|██████▍   | 16/25 [05:34<03:09, 21.07s/it]
#
#
#  68%|██████▊   | 17/25 [05:56<02:51, 21.39s/it]
#
#
#  72%|███████▏  | 18/25 [06:19<02:32, 21.78s/it]
#
#
#  76%|███████▌  | 19/25 [06:42<02:12, 22.16s/it]
#
#
#  80%|████████  | 20/25 [07:02<01:47, 21.46s/it]
#
#
#  84%|████████▍ | 21/25 [07:24<01:26, 21.61s/it]
#
#
#  88%|████████▊ | 22/25 [07:46<01:04, 21.64s/it]
#
#
#  92%|█████████▏| 23/25 [08:05<00:42, 21.12s/it]
#
#
#  96%|█████████▌| 24/25 [08:28<00:21, 21.53s/it]
#
#
# 100%|██████████| 25/25 [08:49<00:00, 21.16s/it]

# %%
color_plot = {'1': 'b', '2': 'r'}
plt.rcParams['figure.figsize'] = (10, 7)
for ttarget in ['1', '2']:
    plt.plot(np.mean(r2_semedo_ds[ttarget], (1, 2)),'.-', linewidth=2, 
             c=color_plot[ttarget],markersize=10, label='semedo_v' + ttarget)
    
    plt.fill_between(x=np.arange(n_ranks), y1=np.mean(r2_semedo_ds[ttarget], (1, 2)), 
                     y2=(np.mean(r2_semedo_ds[ttarget], (1, 2)) + 
                         (np.std(r2_semedo_ds[ttarget], (1, 2)) / np.sqrt(n_runs * n_semedo_ds))), 
                     color=color_plot[ttarget], alpha=0.2)
    
    plt.fill_between(x=np.arange(n_ranks), y1=np.mean(r2_semedo_ds[ttarget], (1, 2)), 
                     y2=(np.mean(r2_semedo_ds[ttarget], (1, 2)) - 
                         (np.std(r2_semedo_ds[ttarget], (1, 2)) / np.sqrt(n_runs * n_semedo_ds))), 
                     color=color_plot[ttarget], alpha=0.2)
#     plt.scatter(-0.3, av_r2_semedo[ttarget].mean(), c=color_plot[ttarget], marker='^', s=90)
#     plt.text(-0.4, av_r2_semedo[ttarget].mean() - 0.01, 'Full Model', c=color_plot[ttarget])
for ttarget in ['1', '2']:
    plt.plot(np.mean(r2_sarah[ttarget], 1), '.-', linewidth=2,
             markersize=10, label='sarah_s' + ttarget)
#     plt.scatter(-0.3, av_r2_sarah[ttarget].mean(), marker='^', s=90)

plt.legend(); plt.xlabel('rank'); plt.ylabel('R2 (mean pm std)'); plt.title('Performance of rank-reduced regression');
# plt.xlim([1, 7])
# plt.ylim([0.08, 0.14])

# %% [markdown]
# ### Difference with paper ->
# I tried std(datasets=mean(runs)) -> large std, and sem(runs=mean(datasets)) -> near-zero std.The final means are equivalent though.
# ### Discrepancy between FM-RRM for Sem1 and Sem2. (Slightly higher Sem2 might be due to overfitting?
# ### Poor performance Sarah's data -> FR-corr? check by hand

# %%
plt.rcParams['figure.figsize'] = (10, 5)
plt.subplot(121)
plt.plot([1, 9], [1, 9], ':', c='k', linewidth=2)
plt.scatter(np.mean(np.argmax(r2_semedo_ds['1'], 0), 0),
            np.mean(np.argmax(r2_semedo_ds['2'], 0), 0), 
            marker='o', facecolors='none', edgecolors='k', s=60, label='semedo')
plt.scatter(np.mean(np.argmax(r2_sarah['1'], 0), 0),
            np.mean(np.argmax(r2_sarah['2'], 0), 0), 
            marker='o', facecolors='orange', edgecolors='orange', s=90, label='sarah')
plt.legend(); 
plt.xlabel('Target V1', color=color_plot['1']); plt.ylabel('Target V2', color=color_plot['2']);
plt.title('Optimal Reduced Rank dimension V1 vs V2')

plt.subplot(122)
diff_dims = np.mean(np.argmax(r2_semedo_ds['1'], 0), 0) - np.mean(np.argmax(r2_semedo_ds['2'], 0), 0)
sem_hist = plt.hist(diff_dims, bins=np.linspace(-1, 7, 9),alpha=0.3, color='k')
plt.hist(np.mean(np.argmax(r2_sarah['1'], 0), 0) - np.mean(np.argmax(r2_sarah['2'], 0), 0),
         bins=np.linspace(-1, 7, 9), bottom=sem_hist[0],
                    alpha=0.5, color='orange')
plt.xlabel('Difference dimensions V1 - V2'); plt.ylabel('Data sets');
plt.title('Distribution of differences \n optimal dimesion per dataset');

sns.despine()

# %% [markdown]
# # Intrinsic dimensionality of target data sets:

# %%
try:
    del zm_data['semedo']
except KeyError:
    pass

semedo_name_list = [x for x in zm_data.keys() if x[:4] == 'seme']
n_semedo_ds = len(semedo_name_list)
n_components = 18
n_cv = 5
dim_semedo_fa = {'1': np.zeros((n_cv, n_components, n_semedo_ds)),
                '2': np.zeros((n_cv, n_components, n_semedo_ds))}

dim_semedo_pca = {'1': np.zeros((n_cv, n_semedo_ds)),
                  '2': np.zeros((n_cv, n_semedo_ds))}

for i_data, data_orig in tqdm(enumerate(semedo_name_list)): 

    source,target = {}, {}
    tmp_s, tmp_t1, tmp_t2 = add_to_source_target(data_or=data_orig, name_1='spikes_v1', 
                                         name_2='spikes_v2', select_method='fr-corr')
    for ttarget in ['1', '2']:
        kf = sklearn.model_selection.KFold(n_splits=n_cv)
        i_kf = 0
        n_total = target[data_orig][ttarget].shape[1]
        for train_inds, test_inds in kf.split(np.arange(n_total)):

            # fit fa
            for i_comp, comp in enumerate(np.arange(1, n_components + 1)):
                fa = sklearn.decomposition.FactorAnalysis(n_components=comp)
                fa.fit(X=target[data_orig][ttarget][:, train_inds].T)
                dim_semedo_fa[ttarget][i_kf, i_comp, i_data] = fa.score(target[data_orig][ttarget][:, test_inds].T)
            
            m_fa = np.argmax(dim_semedo_fa[ttarget][i_kf, :, i_data]) + 1  # Change to one-indexing (because of n_comp loop)
            if m_fa > target[data_orig][ttarget].shape[0]:  # if more components than neurons, set to n-neurons
                m_fa = target[data_orig][ttarget].shape[0]
            fa = sklearn.decomposition.FactorAnalysis(n_components=m_fa)  # fit fa again
            fa.fit(X=target[data_orig][ttarget].T)  # use all data
            
            tmp_pca = sklearn.decomposition.PCA(n_components=m_fa)  # now decompose w/ pca
            tmp_pca.fit(X=fa.components_.T)  
            cum_explvar = np.cumsum(tmp_pca.explained_variance_ratio_)  # cumulative R2
            top_pca_components = np.where(cum_explvar >= 0.95)[0]  # find where > 95% R2
            if len(top_pca_components) == 0:  # if no where, take max
                m_pca = len(top_pca_components)
            else: # otherwise take min of > 95%
                m_pca = np.min(top_pca_components) + 1 # (zero-indexing)
            dim_semedo_pca[ttarget][i_kf, i_data] = m_pca
            
            i_kf +=  1
            

## TODO: put in function and unify semedo and sarah keys


dim_sarah_fa = {'1': np.zeros((n_cv, n_components)),
                '2': np.zeros((n_cv, n_components))}

dim_sarah_pca = {'1': np.zeros(n_cv),
                  '2': np.zeros(n_cv)}
data_orig = 'sarah'
source,target = {}, {}
tmp_s, tmp_t1, tmp_t2 = add_to_source_target(data_or=data_orig, name_1='dff_s1', 
                                     name_2='dff_s2', select_method='fr-corr')
for ttarget in ['1', '2']:
    kf = sklearn.model_selection.KFold(n_splits=n_cv)
    i_kf = 0
    n_total = target[data_orig][ttarget].shape[1]
    for train_inds, test_inds in kf.split(np.arange(n_total)):

        # fit fa
        for i_comp, comp in enumerate(np.arange(1, n_components + 1)):
            fa = sklearn.decomposition.FactorAnalysis(n_components=comp)
            fa.fit(X=target[data_orig][ttarget][:, train_inds].T)
            dim_sarah_fa[ttarget][i_kf, i_comp] = fa.score(target[data_orig][ttarget][:, test_inds].T)

        m_fa = np.argmax(dim_sarah_fa[ttarget][i_kf, :]) + 1  # Change to one-indexing (because of n_comp loop)
        if m_fa > target[data_orig][ttarget].shape[0]:  # if more components than neurons, set to n-neurons
            m_fa = target[data_orig][ttarget].shape[0]
        fa = sklearn.decomposition.FactorAnalysis(n_components=m_fa)  # fit fa again
        fa.fit(X=target[data_orig][ttarget].T)  # use all data

        tmp_pca = sklearn.decomposition.PCA(n_components=m_fa)  # now decompose w/ pca
        tmp_pca.fit(X=fa.components_.T)  
        cum_explvar = np.cumsum(tmp_pca.explained_variance_ratio_)  # cumulative R2
        top_pca_components = np.where(cum_explvar >= 0.95)[0]  # find where > 95% R2
        if len(top_pca_components) == 0:  # if no where, take max
            m_pca = len(top_pca_components)
        else: # otherwise take min of > 95%
            m_pca = np.min(top_pca_components) + 1 # (zero-indexing)
        dim_sarah_pca[ttarget][i_kf] = m_pca

        i_kf +=  1
# Out:
# 4it [02:18, 34.67s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-9f4f7616e983> in <module>
#      28             for i_comp, comp in enumerate(np.arange(1, n_components + 1)):
#      29                 fa = sklearn.decomposition.FactorAnalysis(n_components=comp)
# ---> 30                 fa.fit(X=target[data_orig][ttarget][:, train_inds].T)
#      31                 dim_semedo_fa[ttarget][i_kf, i_comp, i_data] = fa.score(target[data_orig][ttarget][:, test_inds].T)
#      32
#
# ~/.conda/envs/py37/lib/python3.7/site-packages/sklearn/decomposition/factor_analysis.py in fit(self, X, y)
#     214             # SMALL helps numerics
#     215             sqrt_psi = np.sqrt(psi) + SMALL
# --> 216             s, V, unexp_var = my_svd(X / (sqrt_psi * nsqrt))
#     217             s **= 2
#     218             # Use 'maximum' here to avoid sqrt problems.
#
# ~/.conda/envs/py37/lib/python3.7/site-packages/sklearn/decomposition/factor_analysis.py in my_svd(X)
#     205                 _, s, V = randomized_svd(X, n_components,
#     206                                          random_state=random_state,
# --> 207                                          n_iter=self.iterated_power)
#     208                 return s, V, squared_norm(X) - squared_norm(s)
#     209         else:
#
# ~/.conda/envs/py37/lib/python3.7/site-packages/sklearn/utils/extmath.py in randomized_svd(M, n_components, n_oversamples, n_iter, power_iteration_normalizer, transpose, flip_sign, random_state)
#     332
#     333     Q = randomized_range_finder(M, n_random, n_iter,
# --> 334                                 power_iteration_normalizer, random_state)
#     335
#     336     # project M to the (k + p) dimensional space using the basis vectors
#
# ~/.conda/envs/py37/lib/python3.7/site-packages/sklearn/utils/extmath.py in randomized_range_finder(A, size, n_iter, power_iteration_normalizer, random_state)
#     224     # Sample the range of A using by linear projection of Q
#     225     # Extract an orthonormal basis
# --> 226     Q, _ = linalg.qr(safe_sparse_dot(A, Q), mode='economic')
#     227     return Q
#     228
#
# ~/.conda/envs/py37/lib/python3.7/site-packages/sklearn/utils/extmath.py in safe_sparse_dot(a, b, dense_output)
#     140         return ret
#     141     else:
# --> 142         return np.dot(a, b)
#     143
#     144
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
plt.rcParams['figure.figsize'] = (12, 4)
plt.subplot(131)
plt.plot([1, 9], [1, 9], ':', c='k', linewidth=2)
plt.scatter(dim_semedo_pca['1'].mean(0),
            dim_semedo_pca['2'].mean(0), 
            marker='o', facecolors='none', edgecolors='k', s=60, label='semedo')
plt.scatter(dim_sarah_pca['1'].mean(0),
            dim_sarah_pca['2'].mean(0), 
            marker='o', facecolors='orange', edgecolors='orange', s=90, label='sarah')
plt.legend(); 
plt.xlabel('Target V1', color=color_plot['1']); plt.ylabel('Target V2', color=color_plot['2']);
plt.title('Intrinsic dimensionality V1 vs V2')

plt.subplot(132)
diff_dims = dim_semedo_pca['1'].mean(0) - dim_semedo_pca['2'].mean(0)
sem_hist = plt.hist(diff_dims, bins=np.linspace(-7, 7, 9),alpha=0.3, color='k')
plt.hist(dim_sarah_pca['1'].mean(0) - dim_sarah_pca['2'].mean(0),
         bins=np.linspace(-7, 7, 9), bottom=sem_hist[0],
                    alpha=0.5, color='orange')
plt.xlabel('Difference dimensions V1 - V2'); plt.ylabel('Data sets');
plt.title('Distribution of differences \n intrinisc dimesion per dataset');

plt.subplot(133)
plt.plot([1, 9], [1, 9], ':', c='k', linewidth=2)
for ttarget in ['1', '2']:
    plt.scatter(dim_semedo_pca[ttarget].mean(0),
            np.mean(np.argmax(r2_semedo_ds[ttarget], 0), 0), 
            marker='o', facecolors='none', edgecolors=color_plot[ttarget], s=60, label='semedo_' + ttarget)
    plt.scatter(dim_sarah_pca[ttarget].mean(0),
            np.mean(np.argmax(r2_sarah[ttarget], 0), 0), 
            marker='o', s=60, label='sarah_' + ttarget)

plt.xlabel('Target population dimensionality')
plt.ylabel('Number of predictive dimensions');
plt.legend()
sns.despine()

# %% [markdown]
# ## DECODE stimulus

# %%
## Do reshape by hand because of messy reshaping issues
# neurons x times = 970/310 (= n_neurons * n_tpt)
# stimuli x trials = 3200 (= n_stim * n_trials)

# 1) loop through trials; reshape zm_data to 970x400
# 2) loop through stimuli; concat to 970 x 3200 
# 3) Train / test separatin on 3200 (stratified?)

# %%
## For decoding, we need to reshape the Semedo data; because we want to pool 
## all stimuli (otherwise we can't decode). Furthermore, we want to consider all
## (10) time points.

def create_concat_semedo_data(zm_data_set=zm_data, i_m=1):
    n_neurons = {}
    
    list_ds = ['spikes_v1', 'spikes_v2']
    n_neurons['spikes_v1'], n_times = zm_data_set[f'semedo_m{i_m}_st1']['spikes_v1'].shape
    n_neurons['spikes_v2'] = zm_data_set[f'semedo_m{i_m}_st1']['spikes_v2'].shape[0]
    n_tpt = 10  # time points per trial (hard coded from semedo)
    n_trials = int(n_times / n_tpt)
    n_stim = 8  # number of stimuli (hard coded from semedo)

    reshape_zm_data = {}
    concat_neuron_data = {ds: np.zeros((n_neurons[ds] * n_tpt, n_trials * n_stim)) for ds in list_ds}
    concat_stim_labels = np.zeros(n_trials * n_stim)
    for i_stim in range(1, n_stim + 1):
        d_name = f'semedo_m{i_m}_st{i_stim}'
        reshape_zm_data[d_name] = {}
        for ds in list_ds:
            reshape_zm_data[d_name][ds] = np.zeros((n_neurons[ds] * n_tpt, n_trials))
            for i_trial in range(n_trials):
                # reshape neurons x times (concats time traces of neurons)
                reshape_zm_data[d_name][ds][:, i_trial] = np.reshape(zm_data_set[d_name][ds][:, (i_trial * n_tpt):((i_trial + 1) * n_tpt)], -1)
            concat_neuron_data[ds][:, ((i_stim - 1) * n_trials):(i_stim * n_trials)] = reshape_zm_data[d_name][ds]
        concat_stim_labels[((i_stim - 1) * n_trials):(i_stim * n_trials)] = i_stim
    return concat_neuron_data, concat_stim_labels

concat_neuron_data, concat_stim_labels = create_concat_semedo_data()

# %%
## Create train/test generator:
n_cv = 5
list_ds = ['spikes_v1', 'spikes_v2']
ds = 'spikes_v1'  # arbitrary; only needed to extract n_trials
splitter = sklearn.model_selection.StratifiedShuffleSplit(n_splits=n_cv)  # test_size=0.2
gen_split = splitter.split(concat_neuron_data[ds].T, concat_stim_labels)

svm_score = {ds: np.zeros(n_cv) for ds in list_ds}
i_cv = 0
for train, test in gen_split:
    for ds in list_ds:
        svm = sklearn.svm.SVC(kernel='linear')  # regularization to default value -> is very low; could be enlarged (by e.g. 'C'=0.001)
        svm.fit(concat_neuron_data[ds][:, train].T, concat_stim_labels[train])
        # The default svm score metric is np.mean(predicted == true); i.e. the ratio of correctly predicted labels
        svm_score[ds][i_cv] = svm.score(concat_neuron_data[ds][:, test].T, concat_stim_labels[test])
    i_cv += 1

# %%
plt.rcParams['figure.figsize'] = (8, 3)
plt.subplots_adjust(wspace=0.3)

## Predict the last cv:
plt.subplot(121)
ds = 'spikes_v2'
plt.hist2d(np.squeeze(concat_stim_labels[test]),
           np.squeeze(svm.predict(concat_neuron_data[ds][:, test].T)), bins=8)
plt.xlabel('True stimulus'); plt.ylabel('Predicted stimulus'); 
plt.title(f'Predictions of {ds}, for one CV')
plt.colorbar()

plt.subplot(122)

sns.stripplot(x='ds', y='svm_score', 
              data=pd.melt(pd.DataFrame(svm_score), var_name='ds', value_name='svm_score'))
plt.title('SVM score (i.e. ratio of correct labels)');

# %%
print(svm.coef_.shape)
# print((8 * 7)/ 2)

plt.bar(np.arange(31), 
        np.sort(np.sum(np.reshape(np.sum(np.abs(svm.coef_), 0), (31, 10), order='C'), 1)))
# Out:
# (28, 310)
# <BarContainer object of 31 artists>

# %% [markdown]
# ## Correlation DEC & RRR performance per neuron

# %%
rrank = 2
n_cv = 1
n_runs = 5  # source & target generations
n_tpt = 10
# fix random seed?

## Concat data neurons x (time & trials) for RRR
## Concat data (neurons & time) x trials for DEC

i_m = 1
## assuming all stimuli have same amount of neurons ( I belive i hard coded this matlab export script)
## For this RRR we also concatenate the neurons; in this case because we want to predict
## the entire time trace; instead of just for 1 stimulus. This mitigates performance however,
## so perhaps this could be changed

concat_neurons_rrr = {x: np.zeros((zm_data[f'semedo_m{i_m}_st1'][x].shape[0], 32000)) for x in ['spikes_v1', 'spikes_v2']}
for xx in ['spikes_v1', 'spikes_v2']:
    for i_stim in range(1, 9):
        concat_neurons_rrr[xx][:, ((i_stim - 1) * 4000):(i_stim * 4000)] = zm_data[f'semedo_m{i_m}_st{i_stim}'][xx]
        
assert (concat_neurons_rrr['spikes_v1'][:, 16000:20000] == zm_data['semedo_m1_st5']['spikes_v1']).all()  # double check reshape

r2_rrr = {'1': np.zeros((n_runs, n_semedo_ds)),
          '2': np.zeros((n_runs, n_semedo_ds))}  # save population R2 values

def create_full_inds(ori, n_add=10):
    """Create indices to index all time points per neuron"""
    tmp = np.array([])
    for ii in range(n_add):
        new_arr = ori * n_add + ii
        tmp = np.concatenate((tmp, new_arr))
    return np.sort(tmp).astype('int')

rrr_source_contr, dec_source_contr = {}, {}  # save coefs/weights

for run in tqdm(range(n_runs)): # loop through different source/target initisations
    data_orig = f'semedo_m{i_m}_st1'  # pick a name for the sake of source/target sampling
    source,target = {}, {}
    inds = {}
    inds['source'], inds['t1'], inds['t2'] = add_to_source_target(data_or=data_orig, name_1='spikes_v1', 
                                         name_2='spikes_v2', select_method='fr-corr')
    
    # RRR:
    for ttarget in ['1', '2']:
        rrr_model, r2_scores = red_rank_regression(sdata=concat_neurons_rrr['spikes_v1'][inds['source'], 8000:12000], 
                                            rank=rrank,
                                            tdata=concat_neurons_rrr[f'spikes_v{ttarget}'][inds[f't{ttarget}'], 8000:12000])
        print(f'Run {run} target {ttarget} R2 {r2_scores}')
#             r2_semedo_ds[ttarget][run, i_data] = np.mean(r2_scores)
        if ttarget == '1':
            rrr_source_contr[run] = np.squeeze(np.array(np.sum(np.abs(rrr_model.A), 0)))


    # DEC:
    concat_neuron_data, concat_stim_labels = create_concat_semedo_data()

    full_inds = {}
    for xx in ['source', 't1', 't2']:
        full_inds[xx] = create_full_inds(inds[xx], n_add=10)

    concat_neurons_dec = {}
    concat_neurons_dec['source'] = concat_neuron_data['spikes_v1'][full_inds['source'], :]
    concat_neurons_dec['t1'] = concat_neuron_data['spikes_v1'][full_inds['t1'], :]
    concat_neurons_dec['t2'] = concat_neuron_data['spikes_v2'][full_inds['t2'], :]

    splitter = sklearn.model_selection.StratifiedShuffleSplit(n_splits=n_cv, 
                                                      test_size=0.2)  # 20 % test size
    gen_split = splitter.split(concat_neuron_data['spikes_v1'].T, concat_stim_labels)

    dec, dec_score, dec_contribution = {}, {}, {}

    for train, test in gen_split:
        for pop in concat_neurons_dec.keys():
#             dec[pop] = sklearn.svm.SVC(kernel='linear')  # add regularizer?
            dec[pop] = sklearn.linear_model.LogisticRegression(solver='newton-cg', multi_class='multinomial')
            dec[pop].fit(concat_neurons_dec[pop][:, train].T, concat_stim_labels[train])
            # Their score metric is np.mean(predicted == true); i.e. the ratio of correctly predicted labels
            dec_score[pop] = dec[pop].score(concat_neurons_dec[pop][:, test].T, concat_stim_labels[test])
            dec_contribution[pop] = np.sum(np.abs(dec[pop].coef_), 0)
            dec_contribution[pop] = np.sum(np.reshape(dec_contribution[pop], 
                                                      (int(len(full_inds[pop]) / n_tpt), n_tpt)), 1)  # reshape back to neurons x times
        dec_source_contr[run] = dec_contribution['source']
    print(f'DEC scores {dec_score}')
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# Run 0 target 1 R2 0.02449041869393976
# Run 0 target 2 R2 0.04387256241679004
#  20%|██        | 1/5 [00:01<00:07,  1.96s/it]
# DEC scores {'source': 1.0, 't1': 0.978125, 't2': 0.7140625}
# Run 1 target 1 R2 0.04424053408667111
# Run 1 target 2 R2 0.0512728079407872
#  40%|████      | 2/5 [00:03<00:05,  1.95s/it]
# DEC scores {'source': 1.0, 't1': 0.9671875, 't2': 0.7171875}
# Run 2 target 1 R2 0.011359988587633273
# Run 2 target 2 R2 0.04543040163002972
#  60%|██████    | 3/5 [00:05<00:03,  2.00s/it]
# DEC scores {'source': 1.0, 't1': 0.9765625, 't2': 0.70625}
# Run 3 target 1 R2 0.019472451090749333
# Run 3 target 2 R2 0.04439898366264254
#  80%|████████  | 4/5 [00:08<00:02,  2.21s/it]
# DEC scores {'source': 1.0, 't1': 0.9765625, 't2': 0.728125}
# Run 4 target 1 R2 0.03738628005552021
# Run 4 target 2 R2 0.0455975932148269
# 100%|██████████| 5/5 [00:11<00:00,  2.26s/it]
# DEC scores {'source': 1.0, 't1': 0.99375, 't2': 0.7390625}

# %%
rs_coef = dec[pop].coef_.reshape(8, inds[pop].shape[0], n_tpt)
assert (dec[pop].coef_[2, 20:30] == rs_coef[2, 2, :]).all()
mean_coef = np.mean(rs_coef, 2)
# print(mean_coef.shape)
print(f'Population: {pop}, test score: {dec_score[pop]}')

km = sklearn.cluster.KMeans(n_clusters=8)
km.fit(mean_coef.T)
new_inds = np.argsort(km.labels_)
ordered_coefs = mean_coef[:, new_inds]
# print(new_inds)
color_lim = 0.9 * np.max(np.abs(ordered_coefs))
plt.imshow(ordered_coefs, cmap='BrBG', vmin=-1* color_lim, vmax=color_lim)
# plt.colorbar(); 
plt.xlabel('Neuron id'); plt.ylabel('Stimulus id')
plt.title('Sorted neuron-stimulus weight in \n multiclass logistic regression (mean across time bins)');
# Out:
# Population: t2, test score: 0.7390625

# %%
## Double check FR-consistent sampling

# plt.rcParams['figure.figsize'] = (4, 3)
# plot_bins = np.linspace(0, 50, 11)
# plt.hist([zm_data[f'semedo_m{i_m}_st1']['spikes_v1_mean'][inds['t1'], :].sum(1),
#           zm_data[f'semedo_m{i_m}_st1']['spikes_v2_mean'][inds['t2'], :].sum(1)],
#          label=['target 1', 'target 2'], bins=plot_bins)
# plt.xlabel('Firing Rate (Hz)'); plt.ylabel('Frequency'); plt.legend()
# plt.title('Histogram of FR-consistent sampling\n of target distributions');
# # zm_data['semedo_m1_st1']['spikes_v1_mean'].sum(1)

# %%
rrr_all = np.zeros((n_source['semedo_m1_st1'], n_runs))
dec_all = np.zeros((n_source['semedo_m1_st1'], n_runs))

plt.rcParams['figure.figsize'] = (7, 7)
for run in range(n_runs):
    rrr_source_contr[run] = np.squeeze(np.array(rrr_source_contr[run]))
    rrr_all[:, run] = rrr_source_contr[run]
    dec_all[:, run] = dec_source_contr[run]
    
rrr_all = rrr_all.reshape(-1)
dec_all = dec_all.reshape(-1)

# sns.regplot(rrr_all, dec_all)
print(np.corrcoef(rrr_all, dec_all)[1, 0])
print(scipy.stats.pearsonr(rrr_all, dec_all))
for run in range(n_runs):
    
    plt.scatter(dec_source_contr[run], rrr_source_contr[run], s=12)
    sns.regplot(dec_source_contr[run], rrr_source_contr[run])
    print(dec_source_contr[run].shape, rrr_source_contr[run].shape)
    print(np.corrcoef(dec_source_contr[run], rrr_source_contr[run])[1, 0])
plt.xlabel('RRR contribution'); plt.ylabel('DEC contribution'); 
plt.title(f'Contribution of source neurons with rank = {rrank} \nEach color is a different source/target initialization ({n_runs} total)');
# plt.yscale('log')
# Out:
# -0.1032183718310212
# (-0.10321837183102116, 0.04577302807464853)
# (75,) (75,)
# -0.1851928920925852
# (75,) (75,)
# -0.06736134227185557
# (75,) (75,)
# 0.027515988387167015
# (75,) (75,)
# -0.22841067894927272
# (75,) (75,)
# -0.09768535826281967

# %%
## Turn concat_neuron_data into function
## Call it for SVM computation
## Check source SVM (for all stim) vs RRR.A (mean pm std of all stim) contribution
## Do multiple source/target runs

## Expand to target:
## let RRR function return individual R2 values
## Check target SVM (for all stim) vs RRR R2 metric (mean pm std of all stim)
## Multiple runs

## Take top n% neurons of RRR contribution
## Decode with SVM on their activity
## Vary n

# %%
n_cv = 30
ds_list = ['spikes_v1', 'spikes_v2']
dec_scores = {}
n_dec_neurons_arr = {}

for ds in ds_list:

    dec_data = concat_neuron_data[ds].T
    n_dec_neurons = int(dec_data.shape[1] / n_tpt)
    n_dec_neurons_arr[ds] = np.arange(1, np.minimum(n_dec_neurons, 40), 2)

    tmp_dec = np.zeros((dec_data.shape[0], n_dec_neurons))
    for nn in range(n_dec_neurons):
        assert dec_data[:, (10 * nn):(10 * (nn + 1))].shape[1] == n_tpt
        tmp_dec[:, nn] = np.mean(dec_data[:, (10 * nn):(10 * (nn + 1))], 1) # take mean over time bins. This is done to avoid having weights for each time bin. Performance is a little worse than with individual time bins. Performance a bit better/smoother than taking the max.
    dec_data = tmp_dec
    dec_scores[ds] = np.zeros((len(n_dec_neurons_arr[ds]), n_cv))

    for i_loop, n_neurons_loop in tqdm(enumerate(n_dec_neurons_arr[ds])):
        splitter = sklearn.model_selection.StratifiedShuffleSplit(n_splits=n_cv, 
                                                          test_size=0.2)  # 20 % test size
        gen_split = splitter.split(dec_data, concat_stim_labels)
        i_cv = 0
        for train, test in gen_split:
            inds_neurons = np.random.choice(a=n_dec_neurons, size=n_neurons_loop, replace=False)
        
            logreg = sklearn.linear_model.LogisticRegression(solver='newton-cg', multi_class='multinomial')
            logreg.fit(dec_data[train, :][:, inds_neurons], concat_stim_labels[train])
            dec_scores[ds][i_loop, i_cv] = logreg.score(dec_data[test, :][:, inds_neurons], concat_stim_labels[test]) # Their score metric is np.mean(predicted == true); i.e. the ratio of correctly predicted labels
            i_cv += 1
# Out:
# 20it [01:46,  5.33s/it]
# 15it [01:11,  4.78s/it]

# %%
plt.rcParams['figure.figsize'] = (7, 4)

for ii in range(0, 9):
    plt.plot([0, 40], [ii / 8, ii / 8], 
             color='grey', alpha=0.25)
for ds in ds_list:
    plt.errorbar(n_dec_neurons_arr[ds], dec_scores[ds].mean(1), 
                 yerr=dec_scores[ds].std(1) , fmt='.-', linewidth=2, label=ds)
# plt.errorbar(n_neurons_arr, dec_rrr_scores['random'][:, :10].mean(1)[:39],
#              dec_rrr_scores['random'][:, :10].std(1)[:39])
    
    #     plt.ylim([0.25, 1.05]); plt.xlim([-3, 101])
plt.legend(loc='lower right'); plt.xlabel('Number of neurons used (randomly sampled)'); plt.ylabel('Test score (fraction of \ncorrectly classified test trials)');
plt.title(f'Decoding score on test data; mean pm std of {n_cv} CV runs (mean).')
# Out:
# Text(0.5, 1.0, 'Decoding score on test data; mean pm std of 30 CV runs (mean).')

# %%
plt.plot(np.sum(np.power(np.array(full_rrr.A), 2), 0), np.sum(np.abs(np.array(full_rrr.A)), 0), '.')

# %%
rrank = 2
n_cv = 30
n_neurons_arr = np.arange(1, 40, 1)

full_rrr, full_r2 = red_rank_regression(sdata=concat_neurons_rrr['spikes_v1'][:, :], 
                    rank=rrank, n_cv=16,
                    tdata=concat_neurons_rrr[f'spikes_v2'][:, :])
ranking_source = np.sum(np.power(np.array(full_rrr.A), 2), 0)
# ranking_source = np.sum(np.abs(np.array(full_rrr.A)), 0)
sorted_source_n = np.argsort(ranking_source)[::-1]  # large to small
dec_rrr_scores = {x: np.zeros((len(n_neurons_arr), n_cv)) for x in ['small_to_large', 'large_to_small', 'random']}

dec_data = concat_neuron_data['spikes_v1'].T
n_dec_neurons = int(dec_data.shape[1] / n_tpt)

tmp_dec = np.zeros((dec_data.shape[0], n_dec_neurons))
for nn in range(n_dec_neurons):
    assert dec_data[:, (10 * nn):(10 * (nn + 1))].shape[1] == n_tpt
    tmp_dec[:, nn] = np.mean(dec_data[:, (10 * nn):(10 * (nn + 1))], 1) # take mean over time bins. This is done to avoid having weights for each time bin. Performance is a little worse than with individual time bins. Performance a bit better/smoother than taking the max.
dec_data = tmp_dec

# decoding
for i_loop, n_neurons_loop in tqdm(enumerate(n_neurons_arr)):
    splitter = sklearn.model_selection.StratifiedShuffleSplit(n_splits=n_cv, 
                                                      test_size=0.2)  # 20 % test size
    gen_split = splitter.split(dec_data, concat_stim_labels)
    i_cv = 0
    for train, test in gen_split:
        # Large to small RRR neurons
        inds_neurons = sorted_source_n[:n_neurons_loop]  # take n largets contributing 

        logreg = sklearn.linear_model.LogisticRegression(solver='newton-cg', multi_class='multinomial')
        logreg.fit(dec_data[train, :][:, inds_neurons], concat_stim_labels[train])
        dec_rrr_scores['small_to_large'][i_loop, i_cv] = logreg.score(dec_data[test, :][:, inds_neurons], concat_stim_labels[test]) # Their score metric is np.mean(predicted == true); i.e. the ratio of correctly predicted labels

        # Small to large RRR neurons
        inds_neurons = sorted_source_n[::-1][:n_neurons_loop]  # take n largets contributing 

        logreg = sklearn.linear_model.LogisticRegression(solver='newton-cg', multi_class='multinomial')
        logreg.fit(dec_data[train, :][:, inds_neurons], concat_stim_labels[train])
        dec_rrr_scores['large_to_small'][i_loop, i_cv] = logreg.score(dec_data[test, :][:, inds_neurons], concat_stim_labels[test]) # Their score metric is np.mean(predicted == true); i.e. the ratio of correctly predicted labels

        # Random neurons
        inds_neurons = np.random.choice(a=n_dec_neurons, size=n_neurons_loop, replace=False)
        
        logreg = sklearn.linear_model.LogisticRegression(solver='newton-cg', multi_class='multinomial')
        logreg.fit(dec_data[train, :][:, inds_neurons], concat_stim_labels[train])
        dec_rrr_scores['random'][i_loop, i_cv] = logreg.score(dec_data[test, :][:, inds_neurons], concat_stim_labels[test]) # Their score metric is np.mean(predicted == true); i.e. the ratio of correctly predicted labels
        i_cv += 1
# Out:
# 39it [09:33, 14.71s/it]

# %%
plt.rcParams['figure.figsize'] = (9, 5)
f, dec_ax = plt.subplots(1, 1)
for ii in range(0, 9):
    dec_ax.plot([0, n_neurons_arr[-1]], [ii / 8, ii / 8], 
             color='grey', alpha=0.25)
for k in dec_rrr_scores.keys():
    dec_ax.errorbar(n_neurons_arr, dec_rrr_scores[k].mean(1)[:39], 
                 dec_rrr_scores[k].std(1)[:39], label=k, linewidth=2)

# ds = 'spikes_v2'
# plt.errorbar(n_dec_neurons_arr[ds], dec_scores[ds].mean(1), 
#                  yerr=dec_scores[ds].std(1) , fmt='.-', linewidth=2, label=ds)

dec_ax.legend(loc='lower right'); 
dec_ax.set_xlabel(f'Number of neurons used for decoding (out of {len(sorted_source_n)} total in V1)');
dec_ax.set_ylabel('Decoding test score (fraction correct)')
dec_ax.set_title(f'V1 decoding scores (mean $\pm$ std) with {n_cv} CV folds; for Semedo ea dataset {i_m}' + 
                 f'\nfor RRR-contribution sorted (both increasing and decreasing)'  +
                 f'\nand randomly selected number of neurons.')
dec_ax.set_yticks(np.linspace(0, 1, 9)); 
dec_ax.set_yticklabels([f'{ii}/8' for ii in range(9)])
sns.despine()

# %%
n_neurons_regime = 3
rrr_metric = 'L1'  # L1 or L2
if rrr_metric == 'L2':
    ranking_source = np.sum(np.power(np.array(full_rrr.A), 2), 0)
elif rrr_metric == 'L1':
    ranking_source = np.sum(np.abs(np.array(full_rrr.A)), 0)

n_combs = 1000
rrr_perf_regime = np.zeros(n_combs)
dec_perf_regime = np.zeros(n_combs)
# print(len(list(itertools.combinations(np.arange(full_rrr.A.shape[1]), 3))))
# for comb in itertools.combinations(np.arange(96), 3):
    
    
splitter = sklearn.model_selection.StratifiedShuffleSplit(n_splits=1, 
                                                      test_size=0.2)  # 20 % test size
gen_split = splitter.split(dec_data, concat_stim_labels) 
for train, test in gen_split:
    pass

for comb in tqdm(range(n_combs)):
    inds_neurons = np.random.choice(a=full_rrr.A.shape[1], size=n_neurons_regime, replace=False)
    rrr_perf_regime[comb] = np.sum(ranking_source[inds_neurons])
    logreg = sklearn.linear_model.LogisticRegression(solver='newton-cg', multi_class='multinomial')
    logreg.fit(dec_data[train, :][:, inds_neurons], concat_stim_labels[train])
    dec_perf_regime[comb] = logreg.score(dec_data[test, :][:, inds_neurons], concat_stim_labels[test]) # Their score metric is np.mean(predicted == true); i.e. the ratio of correctly predicted labels
# Out:
# 100%|██████████| 1000/1000 [01:42<00:00,  9.73it/s]

# %%
inds_neurons = sorted_source_n[:n_neurons_regime]  # take n largets contributing 
rrr_perf_sorted = np.sum(ranking_source[inds_neurons])
logreg = sklearn.linear_model.LogisticRegression(solver='newton-cg', multi_class='multinomial')
logreg.fit(dec_data[train, :][:, inds_neurons], concat_stim_labels[train])
dec_perf_sorted = logreg.score(dec_data[test, :][:, inds_neurons], concat_stim_labels[test]) # Their score metric is np.mean(predicted == true); i.e. the ratio of correctly predicted labels

# %%
# plt.plot(rrr_perf_regime, dec_perf_regime, '.')
ax_pl = sns.jointplot(rrr_perf_regime, dec_perf_regime, s=5)
ax_pl.ax_joint.set_xlabel(f'RRR performance (sum of individual {rrr_metric} norms)'); 
ax_pl.ax_joint.set_ylabel('Decoding performance (Fraction correct)')
plt.plot(np.array([rrr_perf_sorted]), np.array([dec_perf_sorted]), '.r')
plt.suptitle(f'Random subsample of {n_combs} combinations of {n_neurons_regime} neurons in V1')
# Out:
# Text(0.5, 0.98, 'Random subsample of 1000 combinations of 3 neurons in V1')

# %%
# Out:
# (array([0.78261352]), array([0.59375]))
